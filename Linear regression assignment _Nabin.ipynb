# %%
#imporrting all packeages required
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import math
#reading dataset using pandas and providing header to the data
df = pd.read_csv('ex1data1.txt', header = None, names = ['Population','Profit'])

# %%
#printing first five data
df.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
# scatter plot of the dataset
plt.scatter(x=df['Profit'],y=df['Population'])

# %%
# checking the dataset skewness
df.skew()
# Out:
# Population    2.108093
# Profit        1.433373
# dtype: float64

# %% [markdown]
# #As we see that the skewness of the Profit is 1.43 indicate that the  profit data is positively skewed

# %%
#histogram and normal probability plot
import seaborn as sns
from scipy.stats import norm
from scipy import stats
import warnings 
warnings.filterwarnings('ignore')
sns.distplot(df['Profit'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Profit'], plot=plt)

# %%
#checking the missing value of column
df.isnull().sum()
# Out:
# Population    0
# Profit        0
# dtype: int64

# %%
# defining x and y for analysis
X=df.iloc[:,0]
print(X)
y=df.iloc[:,1]
print(y)
# Out:
# 0      6.1101
# 1      5.5277
# 2      8.5186
# 3      7.0032
# 4      5.8598
# 5      8.3829
# 6      7.4764
# 7      8.5781
# 8      6.4862
# 9      5.0546
# 10     5.7107
# 11    14.1640
# 12     5.7340
# 13     8.4084
# 14     5.6407
# 15     5.3794
# 16     6.3654
# 17     5.1301
# 18     6.4296
# 19     7.0708
# 20     6.1891
# 21    20.2700
# 22     5.4901
# 23     6.3261
# 24     5.5649
# 25    18.9450
# 26    12.8280
# 27    10.9570
# 28    13.1760
# 29    22.2030
#        ...
# 67    10.2360
# 68     5.4994
# 69    20.3410
# 70    10.1360
# 71     7.3345
# 72     6.0062
# 73     7.2259
# 74     5.0269
# 75     6.5479
# 76     7.5386
# 77     5.0365
# 78    10.2740
# 79     5.1077
# 80     5.7292
# 81     5.1884
# 82     6.3557
# 83     9.7687
# 84     6.5159
# 85     8.5172
# 86     9.1802
# 87     6.0020
# 88     5.5204
# 89     5.0594
# 90     5.7077
# 91     7.6366
# 92     5.8707
# 93     5.3054
# 94     8.2934
# 95    13.3940
# 96     5.4369
# ...

# %%
# from sklearn importing train_test splitter
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8)

# %%
#X_train

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train=X_train[:,np.newaxis]
y_train=y_train[:,np.newaxis]

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
#from sklearn importing linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
m=lr.coef_

# %%
c=lr.intercept_

# %%
p11=lr.intercept_ + lr.coef_*11
p11
# Out:
# array([[9.30885419]])

# %%
X_test= X_test[:,np.newaxis]

# %%
y_test= y_test[:,np.newaxis]

# %%
y_pred =lr.predict(X_test)
#plt.scatter(X_train,y_train)
plt.plot(X_test,y_test,'r*')
plt.plot(X_test,y_pred,'b*')
plt.show()

# %%
#y_pred

# %%
# from sklearn import r2 score and mean squared error
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)

# %%
r_squared = r2_score(y_test, y_pred)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 4.924039391466106
# r_square_value : 0.8443938524846912

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
plt.plot(X_test,y_pred, color="blue", linewidth=2.5, linestyle="-")
plt.scatter(X_test,y_test,color="red")
plt.xlabel('Index', fontsize=18)    # X-label
plt.ylabel('ytest-ypred', fontsize=16)
# Out:
# Text(0, 0.5, 'ytest-ypred')

# %%
#At first we check our target variable
sns.distplot(df['Profit'])
print('Skewness: %f', df['Profit'].skew())
print("Kurtosis: %f" % df['Profit'].kurt())
# Out:
# Skewness: %f 1.4333727469854676
# Kurtosis: 1.972124
