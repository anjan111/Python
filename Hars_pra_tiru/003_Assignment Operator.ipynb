# %% [markdown]
# Assignment ( = ):

# %%
a = 10
b = a
c =a+b

# %%
a
# Out:
# 10

# %%
a =a+b
a
# Out:
# 20

# %%
a = 10
b = a
c =a+b

# %%
a += b  # a =a+b
a
# Out:
# 20

# %%
a *=b # a = a*b
a
# Out:
# 200
